# %%
import os
import sys

print(os.path.dirname(sys.executable))
# Out:
# C:\ProgramData\Anaconda3

# %%
import pandas as pd

# %%
import gender_guesser.detector as gender

# %%
d = gender.Detector()

# %%
print(d.get_gender(u"Andy"))
# Out:
# male

# %%
data = pd.read_csv('')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.shape
# Out:
# (352097, 12)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  id  is_superuser                  last_login  \
# 0           0             0   1          True  2020-06-01T07:05:24.296267
# 1           1             1   2         False  2021-10-14T13:37:33.156884
# 2           2             2   5         False  2019-07-04T18:18:45.704794
# 3           3             3  13         False  2020-12-18T09:53:42.772098
# 4           4             4  20         False  2019-07-10T13:07:57.564663
#
#        first_name  is_active                 date_joined zip_code  \
# 0  Administracion       True  2019-06-03T21:06:46.106233        0
# 1          Ariana       True   2019-07-01T17:03:54.84149     6700
# 2            Erik       True  2019-07-01T20:01:38.841529    11000
# 3        Fernando       True  2019-07-02T02:25:30.984091    11206
# 4         Yoandre       True  2019-07-02T10:38:43.927483    27017
#
#    total_orders  success_purchases   gender
# 0             2                  0  unknown
# ...

# %%
#data['first_name'] = data['first_name'].apply(lambda x: x.title())

# %%
data['gender'] = data['first_name'].apply(lambda x:d.get_gender(x))

# %%
data.sample(15)
# Out:
#         Unnamed: 0  Unnamed: 0.1      id  is_superuser  \
# 128956      128956        128956  132994         False
# 117295      117295        117295  121163         False
# 59800        59800         59800   62096         False
# 339814      339814        339814  349775         False
# 247833      247833        247833  255474         False
# 70132        70132         70132   72874         False
# 35002        35002         35002   36017         False
# 167126      167126        167126  172624         False
# 185868      185868        185868  191969         False
# 335896      335896        335896  345764         False
# 350250      350250        350250  360511         False
# 117562      117562        117562  121435         False
# 90125        90125         90125   93523         False
# 302221      302221        302221  311173         False
# 166209      166209        166209  171656         False
#
#                         last_login first_name  is_active  \
# ...

# %%
data['gender'].value_counts(normalize=True)
# Out:
# female           0.439086
# male             0.363843
# unknown          0.174500
# mostly_male      0.010946
# mostly_female    0.007961
# andy             0.003664
# Name: gender, dtype: float64

# %%
data[data['gender']=='unknown'].sample(20)
# Out:
#         Unnamed: 0  Unnamed: 0.1      id  is_superuser  \
# 234731      234731        234731  242048         False
# 180797      180797        180797  186787         False
# 274656      274656        274656  282936         False
# 221994      221994        221994  228896         False
# 69311        69311         69311   72026         False
# 201254      201254        201254  207698         False
# 55132        55132         55132   57204         False
# 321824      321824        321824  331308         False
# 49592        49592         49592   51424         False
# 145199      145199        145199  149528         False
# 276554      276554        276554  284873         False
# 255563      255563        255563  263390         False
# 341960      341960        341960  351991         False
# 121538      121538        121538  125467         False
# 28316        28316         28316   28991         False
# 13519        13519         13519   13791         False
# ...

# %%
data.to_csv('')
